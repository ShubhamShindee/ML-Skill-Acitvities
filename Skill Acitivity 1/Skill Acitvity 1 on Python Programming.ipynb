# %% [markdown]
# ##                                                       SKILL ACTIVITY NO: 1
#
#     Date:16/06/2020
#     Name:Shubham Machhindra Shinde
#     PRN:71830521D
#     gmail id:shubhamshinde291298@gmail.com
#     School: School of Data Science
#     Program: Machine Learning
#     Batch: ML12
#     Module Name:Python Programming
#     Module Code: ML1201
#
# #### Title:
# Python Programming
#
# #### Problem Statement:
# Get the solutions of each modules questions by python programming
#
# #### Skills/Competencies to be acquired:
#
# Python Programming
#
# Use of Numpy,Pandas,Matplotlib
#
#
# #### 1.What is the purpose of this activity?
#
#     1)to perform python programming
#     2)To know about arrays
#     3)To know about Dataframe
#     4)Data Cleaning
#
# #### 2.Steps performed in this activity.
#
#     1)Solve arrays questions using numpy.
#     2)Solve Pandas DataFrame questions using pandas.
#     3)Data Cleaning of gfm data using numpy,pandas and python programming
#     4)Explore Google Play Store Datasets by python programming
#     5)Histogram using matplotlib of CEO Total Pay
#
#
# #### 3.What resources / materials / equipment / tools did you use for this activity?
#
#     1)Anaconda Jupyter Notebook
#     2)Numpy,Pandas,Matplotlib Libraries
#     3)Previous python study materials
#
# #### 4.What skills did you acquire?
#
#     1)Python Progamming skills
#     2)How to use numpy,pandas,matplotlib
#     3)Data Cleaning
#
#
# #### 5.Time taken to complete the activity?
#
#      2-3 days

# %% [markdown]
# # Arrays and DataFrame
#
# ## Due Tuesday,June 16
#
#
#
# First, set up imports by running the cell below.

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Arrays
#
# As data scientists, we'll often be working with millions or even billions of numbers. For this, we need something faster than a `list`. Instead of lists, we will use *arrays*.
#
# Arrays are provided by a package called [NumPy](http://www.numpy.org/) .  The package is called `numpy`, but it's standard to rename it `np` for brevity.  You can do that with:
#
#     import numpy as np

# %%
import numpy as np

# %% [markdown]
# **Question 1.1** Use `np.arange` to create an array with the multiples of 99 from 0 up to (**and including**) 9999.  (So its elements are 0, 99, 198, 297, etc.)

# %%
#your Code
a=np.arange(0,10000,99)
a
# Out:
# array([   0,   99,  198,  297,  396,  495,  594,  693,  792,  891,  990,
#        1089, 1188, 1287, 1386, 1485, 1584, 1683, 1782, 1881, 1980, 2079,
#        2178, 2277, 2376, 2475, 2574, 2673, 2772, 2871, 2970, 3069, 3168,
#        3267, 3366, 3465, 3564, 3663, 3762, 3861, 3960, 4059, 4158, 4257,
#        4356, 4455, 4554, 4653, 4752, 4851, 4950, 5049, 5148, 5247, 5346,
#        5445, 5544, 5643, 5742, 5841, 5940, 6039, 6138, 6237, 6336, 6435,
#        6534, 6633, 6732, 6831, 6930, 7029, 7128, 7227, 7326, 7425, 7524,
#        7623, 7722, 7821, 7920, 8019, 8118, 8217, 8316, 8415, 8514, 8613,
#        8712, 8811, 8910, 9009, 9108, 9207, 9306, 9405, 9504, 9603, 9702,
#        9801, 9900, 9999])

# %% [markdown]
# **Question 1.2.** Create an array of the time, in seconds, since the start of the month at which each hourly reading was taken. Name it collection_times.
#
# Hint 1: There were 31 days in December, which is equivalent to (31×24
# ) hours or (31×24×60×60) seconds. So your array should have 31×24
#
# elements in it.
#
# Hint 2: The len function works on arrays, too. check its length and make sure it has 31×24
# elements.

# %%
#your code
## here I creat array from 0 to 31*24*60=44640 with step size of 60, we want lengh of an array 31*24=744 element 
collection_time=np.arange(0,44640,60)
collection_time
# Out:
# array([    0,    60,   120,   180,   240,   300,   360,   420,   480,
#          540,   600,   660,   720,   780,   840,   900,   960,  1020,
#         1080,  1140,  1200,  1260,  1320,  1380,  1440,  1500,  1560,
#         1620,  1680,  1740,  1800,  1860,  1920,  1980,  2040,  2100,
#         2160,  2220,  2280,  2340,  2400,  2460,  2520,  2580,  2640,
#         2700,  2760,  2820,  2880,  2940,  3000,  3060,  3120,  3180,
#         3240,  3300,  3360,  3420,  3480,  3540,  3600,  3660,  3720,
#         3780,  3840,  3900,  3960,  4020,  4080,  4140,  4200,  4260,
#         4320,  4380,  4440,  4500,  4560,  4620,  4680,  4740,  4800,
#         4860,  4920,  4980,  5040,  5100,  5160,  5220,  5280,  5340,
#         5400,  5460,  5520,  5580,  5640,  5700,  5760,  5820,  5880,
#         5940,  6000,  6060,  6120,  6180,  6240,  6300,  6360,  6420,
#         6480,  6540,  6600,  6660,  6720,  6780,  6840,  6900,  6960,
#         7020,  7080,  7140,  7200,  7260,  7320,  7380,  7440,  7500,
#         7560,  7620,  7680,  7740,  7800,  7860,  7920,  7980,  8040,
#         8100,  8160,  8220,  8280,  8340,  8400,  8460,  8520,  8580,
#         8640,  8700,  8760,  8820,  8880,  8940,  9000,  9060,  9120,
#         9180,  9240,  9300,  9360,  9420,  9480,  9540,  9600,  9660,
#         9720,  9780,  9840,  9900,  9960, 10020, 10080, 10140, 10200,
#        10260, 10320, 10380, 10440, 10500, 10560, 10620, 10680, 10740,
#        10800, 10860, 10920, 10980, 11040, 11100, 11160, 11220, 11280,
#        11340, 11400, 11460, 11520, 11580, 11640, 11700, 11760, 11820,
#        11880, 11940, 12000, 12060, 12120, 12180, 12240, 12300, 12360,
#        12420, 12480, 12540, 12600, 12660, 12720, 12780, 12840, 12900,
#        12960, 13020, 13080, 13140, 13200, 13260, 13320, 13380, 13440,
#        13500, 13560, 13620, 13680, 13740, 13800, 13860, 13920, 13980,
#        14040, 14100, 14160, 14220, 14280, 14340, 14400, 14460, 14520,
#        14580, 14640, 14700, 14760, 14820, 14880, 14940, 15000, 15060,
#        15120, 15180, 15240, 15300, 15360, 15420, 15480, 15540, 15600,
#        15660, 15720, 15780, 15840, 15900, 15960, 16020, 16080, 16140,
#        16200, 16260, 16320, 16380, 16440, 16500, 16560, 16620, 16680,
#        16740, 16800, 16860, 16920, 16980, 17040, 17100, 17160, 17220,
#        17280, 17340, 17400, 17460, 17520, 17580, 17640, 17700, 17760,
#        17820, 17880, 17940, 18000, 18060, 18120, 18180, 18240, 18300,
#        18360, 18420, 18480, 18540, 18600, 18660, 18720, 18780, 18840,
#        18900, 18960, 19020, 19080, 19140, 19200, 19260, 19320, 19380,
#        19440, 19500, 19560, 19620, 19680, 19740, 19800, 19860, 19920,
#        19980, 20040, 20100, 20160, 20220, 20280, 20340, 20400, 20460,
#        20520, 20580, 20640, 20700, 20760, 20820, 20880, 20940, 21000,
#        21060, 21120, 21180, 21240, 21300, 21360, 21420, 21480, 21540,
#        21600, 21660, 21720, 21780, 21840, 21900, 21960, 22020, 22080,
#        22140, 22200, 22260, 22320, 22380, 22440, 22500, 22560, 22620,
#        22680, 22740, 22800, 22860, 22920, 22980, 23040, 23100, 23160,
#        23220, 23280, 23340, 23400, 23460, 23520, 23580, 23640, 23700,
#        23760, 23820, 23880, 23940, 24000, 24060, 24120, 24180, 24240,
#        24300, 24360, 24420, 24480, 24540, 24600, 24660, 24720, 24780,
#        24840, 24900, 24960, 25020, 25080, 25140, 25200, 25260, 25320,
#        25380, 25440, 25500, 25560, 25620, 25680, 25740, 25800, 25860,
#        25920, 25980, 26040, 26100, 26160, 26220, 26280, 26340, 26400,
#        26460, 26520, 26580, 26640, 26700, 26760, 26820, 26880, 26940,
#        27000, 27060, 27120, 27180, 27240, 27300, 27360, 27420, 27480,
#        27540, 27600, 27660, 27720, 27780, 27840, 27900, 27960, 28020,
#        28080, 28140, 28200, 28260, 28320, 28380, 28440, 28500, 28560,
#        28620, 28680, 28740, 28800, 28860, 28920, 28980, 29040, 29100,
#        29160, 29220, 29280, 29340, 29400, 29460, 29520, 29580, 29640,
#        29700, 29760, 29820, 29880, 29940, 30000, 30060, 30120, 30180,
#        30240, 30300, 30360, 30420, 30480, 30540, 30600, 30660, 30720,
#        30780, 30840, 30900, 30960, 31020, 31080, 31140, 31200, 31260,
#        31320, 31380, 31440, 31500, 31560, 31620, 31680, 31740, 31800,
#        31860, 31920, 31980, 32040, 32100, 32160, 32220, 32280, 32340,
#        32400, 32460, 32520, 32580, 32640, 32700, 32760, 32820, 32880,
#        32940, 33000, 33060, 33120, 33180, 33240, 33300, 33360, 33420,
#        33480, 33540, 33600, 33660, 33720, 33780, 33840, 33900, 33960,
#        34020, 34080, 34140, 34200, 34260, 34320, 34380, 34440, 34500,
#        34560, 34620, 34680, 34740, 34800, 34860, 34920, 34980, 35040,
#        35100, 35160, 35220, 35280, 35340, 35400, 35460, 35520, 35580,
#        35640, 35700, 35760, 35820, 35880, 35940, 36000, 36060, 36120,
#        36180, 36240, 36300, 36360, 36420, 36480, 36540, 36600, 36660,
#        36720, 36780, 36840, 36900, 36960, 37020, 37080, 37140, 37200,
#        37260, 37320, 37380, 37440, 37500, 37560, 37620, 37680, 37740,
#        37800, 37860, 37920, 37980, 38040, 38100, 38160, 38220, 38280,
#        38340, 38400, 38460, 38520, 38580, 38640, 38700, 38760, 38820,
#        38880, 38940, 39000, 39060, 39120, 39180, 39240, 39300, 39360,
#        39420, 39480, 39540, 39600, 39660, 39720, 39780, 39840, 39900,
#        39960, 40020, 40080, 40140, 40200, 40260, 40320, 40380, 40440,
#        40500, 40560, 40620, 40680, 40740, 40800, 40860, 40920, 40980,
#        41040, 41100, 41160, 41220, 41280, 41340, 41400, 41460, 41520,
#        41580, 41640, 41700, 41760, 41820, 41880, 41940, 42000, 42060,
#        42120, 42180, 42240, 42300, 42360, 42420, 42480, 42540, 42600,
#        42660, 42720, 42780, 42840, 42900, 42960, 43020, 43080, 43140,
#        43200, 43260, 43320, 43380, 43440, 43500, 43560, 43620, 43680,
#        43740, 43800, 43860, 43920, 43980, 44040, 44100, 44160, 44220,
#        44280, 44340, 44400, 44460, 44520, 44580])

# %%
len(collection_time)
# Out:
# 744

# %% [markdown]
# **Question 1.3** The powers of 2 ($2^0 = 1$, $2^1 = 2$, $2^2 = 4$, etc) arise frequently in computer science.  (For example, you may have noticed that storage on smartphones or USBs come in powers of 2, like 16 GB, 32 GB, or 64 GB.)  Use `np.arange` and the exponentiation operator `**` to compute the first 30 powers of 2, starting from `2^0`.
#
# *Hint*: Did your kernel "die" when you ran your solution? There is a common incorrect response to this problem that tries to create an array with so many entries that Python gives up. If this happens to you, double-check your answer!
#
# **Expected Output**
# ![image.png](attachment:image.png)

# %%
#your code Here
power_of_2=2**np.arange(30)
(power_of_2)
# Out:
# array([        1,         2,         4,         8,        16,        32,
#               64,       128,       256,       512,      1024,      2048,
#             4096,      8192,     16384,     32768,     65536,    131072,
#           262144,    524288,   1048576,   2097152,   4194304,   8388608,
#         16777216,  33554432,  67108864, 134217728, 268435456, 536870912],
#       dtype=int32)

# %%
a=[]
for i in range (30):
    a.append(2**i)
np.array(a)
# Out:
# array([        1,         2,         4,         8,        16,        32,
#               64,       128,       256,       512,      1024,      2048,
#             4096,      8192,     16384,     32768,     65536,    131072,
#           262144,    524288,   1048576,   2097152,   4194304,   8388608,
#         16777216,  33554432,  67108864, 134217728, 268435456, 536870912])

# %% [markdown]
# **Question 1.4** Get all items between 5 and 10 from a.
#
# Input:
#
# a = np.array([2, 6, 1, 9, 10, 3, 27])
# <br>
# <br>
# Desired Output:
#
# (array([6, 9, 10]),)

# %%
#your code here
a = np.array([2, 6, 1, 9, 10, 3, 27])
b = np.where((a >= 5) & (a <= 10))
a[b]
# Out:
# array([ 6,  9, 10])

# %%
a = np.array([2, 6, 1, 9, 10, 3, 27])
def output(a,x,y):
    out=[]
    for i in range(len(a)):
        if a[i]>=x and a[i]<=y:
            out.append(a[i])
    return np.array(out)
 
output(a,5,10)
# Out:
# array([ 6,  9, 10])

# %% [markdown]
# **Question 1.5** Create the following pattern without hardcoding. Use only numpy functions and the below input array a.
#
# Input:
#
# a = np.array([1,2,3])`
#
# Desired Output:
#
# array([1, 1, 1, 2, 2, 2, 3, 3, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3])
# <br>
# <br>
# Hint:You may use numpy repeat,tile

# %%
a = np.array([1,2,3])
b=np.repeat(a,3)
c=np.tile(a,3)
d=np.concatenate([b,c])  #or np.hstack((b,c))
d
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 3, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3])

# %%
#your code here
a = np.array([1,2,3])
b=np.r_[np.repeat(a,3),np.tile(a,3)]
b
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 3, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3])

# %% [markdown]
# # 2. Pandas DataFrames

# %% [markdown]
# For a collection of things in the world, an array is useful for describing a single attribute of each thing. For example, among the collection of Indian States, an array could describe the land area of each. Dataframes extend this idea by describing multiple attributes for each element of a collection.
#
# In most data science applications, we have data about many entities, but we also have several kinds of data about each entity.

# %% [markdown]
# **Question 2.1** In the cell below, we've created 2 arrays. Using the steps above, assign `top_10_movies` to a DataFrame that has two columns called "Rating" and "Name", which hold `top_10_movie_ratings` and `top_10_movie_names` respectively.
#
# **Expected Output**
# ![image.png](attachment:image.png)

# %%
top_10_movie_ratings = np.array([9.2, 9.2, 9., 8.9, 8.9, 8.9, 8.9, 8.9, 8.9, 8.8])
top_10_movie_names = np.array([
        'The Shawshank Redemption (1994)',
        'The Godfather (1972)',
        'The Godfather: Part II (1974)',
        'Pulp Fiction (1994)',
        "Schindler's List (1993)",
        'The Lord of the Rings: The Return of the King (2003)',
        '12 Angry Men (1957)',
        'The Dark Knight (2008)',
        'Il buono, il brutto, il cattivo (1966)',
        'The Lord of the Rings: The Fellowship of the Ring (2001)'
])

# %%
#your Code
top_10_movies=pd.DataFrame()
top_10_movies["Rating"]=top_10_movie_ratings
top_10_movies["Name"]=top_10_movie_names
top_10_movies
# Out:
#    Rating                                               Name
# 0     9.2                    The Shawshank Redemption (1994)
# 1     9.2                               The Godfather (1972)
# 2     9.0                      The Godfather: Part II (1974)
# 3     8.9                                Pulp Fiction (1994)
# 4     8.9                            Schindler's List (1993)
# 5     8.9  The Lord of the Rings: The Return of the King ...
# 6     8.9                                12 Angry Men (1957)
# 7     8.9                             The Dark Knight (2008)
# 8     8.9             Il buono, il brutto, il cattivo (1966)
# 9     8.8  The Lord of the Rings: The Fellowship of the R...

# %%
my_ranking = [8, 2, 1, 9, 7, 10, 6, 4, 3, 5]

# %% [markdown]
# **Question 2.2**  Create a new DataFrame called `with_ranking` by adding a column named "Ranking" to the table in `top_10_movies`.

# %%
#your code here
top_10_movies['Ranking']=my_ranking
top_10_movies
# Out:
#    Rating                                               Name  Ranking
# 0     9.2                    The Shawshank Redemption (1994)        8
# 1     9.2                               The Godfather (1972)        2
# 2     9.0                      The Godfather: Part II (1974)        1
# 3     8.9                                Pulp Fiction (1994)        9
# 4     8.9                            Schindler's List (1993)        7
# 5     8.9  The Lord of the Rings: The Return of the King ...       10
# 6     8.9                                12 Angry Men (1957)        6
# 7     8.9                             The Dark Knight (2008)        4
# 8     8.9             Il buono, il brutto, il cattivo (1966)        3
# 9     8.8  The Lord of the Rings: The Fellowship of the R...        5

# %% [markdown]
# ##  Functions and CEO Incomes
#
# Let's start with a real data analysis task.  We'll look at the 2015 compensation of CEOs at the 100 largest companies in California.  The data were compiled for a Los Angeles Times analysis [here](http://spreadsheets.latimes.com/california-ceo-compensation/), and ultimately came from [filings](https://www.sec.gov/answers/proxyhtf.htm) mandated by the SEC from all publicly-traded companies.  Two companies have two CEOs, so there are 102 CEOs in the dataset.

# %%
raw_compensation = pd.read_csv('S://ML//datasets/raw_compensation.csv').set_index('Rank')
raw_compensation
# Out:
#                     Name                 Company (Headquarters) Total Pay  \
# Rank
# 1          Mark V. Hurd*                  Oracle (Redwood City)   $53.25
# 2         Safra A. Catz*                  Oracle (Redwood City)   $53.24
# 3         Robert A. Iger                  Walt Disney (Burbank)   $44.91
# 4       Marissa A. Mayer                     Yahoo! (Sunnyvale)   $35.98
# 5           Marc Benioff         salesforce.com (San Francisco)   $33.36
# ...                  ...                                    ...       ...
# 98    Gregory N. Roberts  A-Mark Precious Metals (Santa Monica)    $0.94
# 99       Jose L. Laparte                 PriceSmart (San Diego)    $0.81
# 100          Jack Dorsey                Twitter (San Francisco)    $0.07
# 101         Elon R. Musk               Tesla Motors (Palo Alto)    $0.04
# 102     Lawrence Page***               Alphabet (Mountain View)    $0.00
#
#      % Change Cash Pay Equity Pay Other Pay  \
# Rank
# 1         NaN   $0.95     $52.27     $0.02
# 2         NaN   $0.95     $52.27     $0.02
# 3         -3%  $24.89     $17.28     $2.74
# 4        -15%   $1.00     $34.43     $0.55
# 5        -16%   $4.65     $27.26     $1.45
# ...       ...      ...        ...       ...
# 98       -11%   $0.93      $0.00     $0.02
# 99        -7%   $0.71      $0.00     $0.10
# 100       NaN   $0.00      $0.00     $0.07
# 101        6%   $0.04      $0.00     $0.00
# 102        0%   $0.00      $0.00     $0.00
#
#       Ratio of CEO pay to average industry worker pay
# Rank
# 1                                           362.00000
# 2                                           362.00000
# 3                                           477.00000
# 4                                           342.00000
# 5                                           338.00000
# ...                                               ...
# 98                                           17.00000
# 99                                           32.00000
# 100                                           0.63000
# 101                                           0.46000
# 102                                           0.00001
#
# [102 rows x 8 columns]

# %% [markdown]
# **Question 2.3** You should have found that the values in "Total Pay" column are strings (text). It doesn't make sense to take the average of the text values, so we need to convert them to numbers if we want to do this. Extract the first value in the "Total Pay" column.  It's Mark Hurd's pay in 2015, in *millions* of dollars.  Call it `mark_hurd_pay_string`.

# %%
#your code here
mark_hurd_pay_string=raw_compensation["Total Pay"][1]
mark_hurd_pay_string
# Out:
# '$53.25 '

# %% [markdown]
# **Question 2.3.1** Using code,convert `mark_hurd_pay_string` to a number of *dollars*.
# <br>Hint: you can use split method."

# %%
#your code here
mark_hurd_pay_string.split('$')[1]
# Out:
# '53.25 '

# %% [markdown]
# To compute the average pay, we need to do this for every CEO. But that looks like it would involve copying this code 102 times.
# <br>**Question 2.3.2.** Copy the expression you used to compute `mark_hurd_pay` as the `return` expression of the function below, but replace the specific `mark_hurd_pay_string` with the generic `pay_string` name specified in the first line of the `def` statement.

# %%
#your code here
def convert_pay_string_to_number(pay_string):
    return pay_string.replace("$","")
convert_pay_string_to_number("$53.25")
# Out:
# '53.25'

# %% [markdown]
# #run this cell to check if your code is correct

# %%
convert_pay_string_to_number('$42')
# Out:
# '42'

# %% [markdown]
# **Question 2.3.3** Using apply, make a Daatframe that's a copy of raw_compensation with one more column called "Total_Pay_Dollars". It should be the result of applying convert_pay_string_to_number to the "Total Pay" column, as we did above. Call the new df compensation.

# %%
compensation=pd.DataFrame(raw_compensation)
compensation["Total_Pay_Dollars"]=compensation["Total Pay"].apply(convert_pay_string_to_number).astype(float)
print(compensation["Total_Pay_Dollars"])
compensation
# Out:
# Rank
# 1      53.25
# 2      53.24
# 3      44.91
# 4      35.98
# 5      33.36
#        ...
# 98      0.94
# 99      0.81
# 100     0.07
# 101     0.04
# 102     0.00
# Name: Total_Pay_Dollars, Length: 102, dtype: float64
#                     Name                 Company (Headquarters) Total Pay  \
# Rank
# 1          Mark V. Hurd*                  Oracle (Redwood City)   $53.25
# 2         Safra A. Catz*                  Oracle (Redwood City)   $53.24
# 3         Robert A. Iger                  Walt Disney (Burbank)   $44.91
# 4       Marissa A. Mayer                     Yahoo! (Sunnyvale)   $35.98
# 5           Marc Benioff         salesforce.com (San Francisco)   $33.36
# ...                  ...                                    ...       ...
# 98    Gregory N. Roberts  A-Mark Precious Metals (Santa Monica)    $0.94
# 99       Jose L. Laparte                 PriceSmart (San Diego)    $0.81
# 100          Jack Dorsey                Twitter (San Francisco)    $0.07
# 101         Elon R. Musk               Tesla Motors (Palo Alto)    $0.04
# 102     Lawrence Page***               Alphabet (Mountain View)    $0.00
#
#      % Change Cash Pay Equity Pay Other Pay  \
# Rank
# 1         NaN   $0.95     $52.27     $0.02
# 2         NaN   $0.95     $52.27     $0.02
# 3         -3%  $24.89     $17.28     $2.74
# 4        -15%   $1.00     $34.43     $0.55
# 5        -16%   $4.65     $27.26     $1.45
# ...       ...      ...        ...       ...
# 98       -11%   $0.93      $0.00     $0.02
# 99        -7%   $0.71      $0.00     $0.10
# 100       NaN   $0.00      $0.00     $0.07
# 101        6%   $0.04      $0.00     $0.00
# 102        0%   $0.00      $0.00     $0.00
#
#       Ratio of CEO pay to average industry worker pay  Total_Pay_Dollars
# Rank
# 1                                           362.00000              53.25
# 2                                           362.00000              53.24
# 3                                           477.00000              44.91
# 4                                           342.00000              35.98
# 5                                           338.00000              33.36
# ...                                               ...                ...
# 98                                           17.00000               0.94
# 99                                           32.00000               0.81
# 100                                           0.63000               0.07
# 101                                           0.46000               0.04
# 102                                           0.00001               0.00
#
# [102 rows x 9 columns]

# %%
compensation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 1 to 102
# Data columns (total 9 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Name                                             102 non-null    object
#  1   Company (Headquarters)                           102 non-null    object
#  2   Total Pay                                        102 non-null    object
#  3   % Change                                         81 non-null     object
#  4   Cash Pay                                         102 non-null    object
#  5   Equity Pay                                       102 non-null    object
#  6   Other Pay                                        102 non-null    object
#  7   Ratio of CEO pay to average industry worker pay  102 non-null    float64
#  8   Total_Pay_Dollars                                102 non-null    float64
# dtypes: float64(2), object(7)
# memory usage: 13.0+ KB

# %% [markdown]
# **Question 2.4.** Companies pay executives in a variety of ways: directly in cash; by granting stock or other "equity" in the company; or with ancillary benefits (like private jets).  Compute the proportion of each CEO's pay that was cash.  (Your answer should be an array of numbers, one for each CEO in the dataset.)

# %%
#your code here
compensation['Cash Pay']=compensation['Cash Pay'].apply(convert_pay_string_to_number).astype(float)
CEO_pay_prop=compensation['Cash Pay'] / compensation["Total_Pay_Dollars"]
np.array(CEO_pay_prop)

#or 
#np.array(compensation['Cash Pay'] / compensation["Total_Pay_Dollars"])
# Out:
# array([0.01784038, 0.01784373, 0.55421955, 0.02779322, 0.13938849,
#        0.48711755, 0.19555354, 0.12437059, 0.25993884, 0.35196687,
#        0.3075693 , 0.22138635, 0.13126362, 0.1708126 , 0.23099415,
#        0.06734817, 0.13043478, 0.28004957, 0.33229814, 0.15355805,
#        0.29337748, 0.21829105, 0.31100478, 0.25086147, 0.2299169 ,
#        0.16991643, 0.31795947, 0.26188786, 0.28357143, 0.15654718,
#        0.38168558, 0.28934426, 0.20361248, 0.47650453, 0.45643154,
#        0.36402027, 0.2177626 , 0.24763543, 0.42562724, 0.2610261 ,
#        0.18361836, 0.1444548 , 0.33333333, 0.10834132, 0.20925747,
#        0.97276265, 0.22979552, 0.22789784, 0.37893701, 0.25175527,
#        0.73895582, 0.37018256, 0.2412731 , 0.2133758 , 0.20553781,
#        0.23318872, 0.33664459, 0.3875969 , 0.56094808, 0.11757991,
#        0.35239207, 0.24463007, 0.25      , 0.23712575, 0.43377886,
#        0.31424936, 0.46363636, 0.32585752, 0.24766977, 0.98755187,
#        0.27184466, 0.96207865, 0.31831395, 0.81979321, 0.23795181,
#        0.17530488, 0.21172638, 0.37162162, 0.27288136, 0.26994907,
#        0.55148342, 0.3597786 , 0.        , 0.47154472, 0.47154472,
#        0.29753915, 0.16235294, 0.48529412, 0.46819338, 0.32526882,
#        0.98958333, 0.61130742, 0.67021277, 0.75510204, 0.50837989,
#        0.98809524, 0.98039216, 0.9893617 , 0.87654321, 0.        ,
#        1.        ,        nan])

# %% [markdown]
# ##### Alright, back to our CEOs.  Check out the "% Change" column in `compensation`.  It shows the percentage increase in the CEO's pay from the previous year.  For CEOs with no previous year on record, it instead says "(No previous year)".  The values in this column are *strings*, not numbers, so like the "Total Pay" column, it's not usable without a bit of extra work.
#
# Given your current pay and the percentage increase from the previous year, you can compute your previous year's pay.  For example, if your pay is \\$100 this year, and that's an increase of 50% from the previous year, then your previous year's pay was $\frac{\$100}{1 + \frac{50}{100}}$, or around \$66.66.
#
# **Question 2.5.** Create a new table called `with_previous_compensation`.  It should be a copy of `compensation`, but with the "(No previous year)" CEOs filtered out, and with an extra column called "Previous_Total_Pay".  That column should have each CEO's pay in 2014.
#
# *Hint:* This question takes several steps, but each one is still something you've seen before.  Take it one step at a time, using as many lines as you need.  You can print out your results after each step to make sure you're on the right track.
#
# *Hint 2:* You'll need to define a function to convert percentage strings, like `-15%`, to numbers.  You can do that just above your other code.
#
# *Hint 3:* If you see an error saying "unsupported operand type(s) for +: 'int' and 'Series'", try switching the order of your operation. Instead of writing something like `1 + series`, write `series + 1`.

# %%
def convert_string_to_number(a):
    return a.replace("%","")

def string_to_number(b):
    return b.replace("-","")

#your code Here

with_previous_compensation=compensation
with_previous_compensation['% Change']=with_previous_compensation['% Change'].astype(str).apply(convert_string_to_number)
with_previous_compensation['% Change']=with_previous_compensation['% Change'].apply(string_to_number).astype(float)

with_previous_compensation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 1 to 102
# Data columns (total 9 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Name                                             102 non-null    object
#  1   Company (Headquarters)                           102 non-null    object
#  2   Total Pay                                        102 non-null    object
#  3   % Change                                         81 non-null     float64
#  4   Cash Pay                                         102 non-null    float64
#  5   Equity Pay                                       102 non-null    object
#  6   Other Pay                                        102 non-null    object
#  7   Ratio of CEO pay to average industry worker pay  102 non-null    float64
#  8   Total_Pay_Dollars                                102 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 13.0+ KB

# %%
with_previous_compensation.head()
# Out:
#                   Name          Company (Headquarters) Total Pay  % Change  \
# Rank
# 1        Mark V. Hurd*           Oracle (Redwood City)   $53.25        NaN
# 2       Safra A. Catz*           Oracle (Redwood City)   $53.24        NaN
# 3       Robert A. Iger           Walt Disney (Burbank)   $44.91        3.0
# 4     Marissa A. Mayer              Yahoo! (Sunnyvale)   $35.98       15.0
# 5         Marc Benioff  salesforce.com (San Francisco)   $33.36       16.0
#
#       Cash Pay Equity Pay Other Pay  \
# Rank
# 1         0.95    $52.27     $0.02
# 2         0.95    $52.27     $0.02
# 3        24.89    $17.28     $2.74
# 4         1.00    $34.43     $0.55
# 5         4.65    $27.26     $1.45
#
#       Ratio of CEO pay to average industry worker pay  Total_Pay_Dollars
# Rank
# 1                                               362.0              53.25
# 2                                               362.0              53.24
# 3                                               477.0              44.91
# 4                                               342.0              35.98
# 5                                               338.0              33.36

# %%
with_previous_compensation['previous_total_pay']=with_previous_compensation['Total_Pay_Dollars']/(1+(with_previous_compensation['% Change']/100))
with_previous_compensation
# Out:
#                     Name                 Company (Headquarters) Total Pay  \
# Rank
# 1          Mark V. Hurd*                  Oracle (Redwood City)   $53.25
# 2         Safra A. Catz*                  Oracle (Redwood City)   $53.24
# 3         Robert A. Iger                  Walt Disney (Burbank)   $44.91
# 4       Marissa A. Mayer                     Yahoo! (Sunnyvale)   $35.98
# 5           Marc Benioff         salesforce.com (San Francisco)   $33.36
# ...                  ...                                    ...       ...
# 98    Gregory N. Roberts  A-Mark Precious Metals (Santa Monica)    $0.94
# 99       Jose L. Laparte                 PriceSmart (San Diego)    $0.81
# 100          Jack Dorsey                Twitter (San Francisco)    $0.07
# 101         Elon R. Musk               Tesla Motors (Palo Alto)    $0.04
# 102     Lawrence Page***               Alphabet (Mountain View)    $0.00
#
#       % Change  Cash Pay Equity Pay Other Pay  \
# Rank
# 1          NaN      0.95    $52.27     $0.02
# 2          NaN      0.95    $52.27     $0.02
# 3          3.0     24.89    $17.28     $2.74
# 4         15.0      1.00    $34.43     $0.55
# 5         16.0      4.65    $27.26     $1.45
# ...        ...       ...        ...       ...
# 98        11.0      0.93     $0.00     $0.02
# 99         7.0      0.71     $0.00     $0.10
# 100        NaN      0.00     $0.00     $0.07
# 101        6.0      0.04     $0.00     $0.00
# 102        0.0      0.00     $0.00     $0.00
#
#       Ratio of CEO pay to average industry worker pay  Total_Pay_Dollars  \
# Rank
# 1                                           362.00000              53.25
# 2                                           362.00000              53.24
# 3                                           477.00000              44.91
# 4                                           342.00000              35.98
# 5                                           338.00000              33.36
# ...                                               ...                ...
# 98                                           17.00000               0.94
# 99                                           32.00000               0.81
# 100                                           0.63000               0.07
# 101                                           0.46000               0.04
# 102                                           0.00001               0.00
#
#       previous_total_pay
# Rank
# 1                    NaN
# 2                    NaN
# 3              43.601942
# 4              31.286957
# 5              28.758621
# ...                  ...
# 98              0.846847
# 99              0.757009
# 100                  NaN
# 101             0.037736
# 102             0.000000
#
# [102 rows x 10 columns]

# %% [markdown]
# ## 3. Data Cleaning

# %%
gfm_data =pd.read_csv('S:/ML/datasets/gfm_data.csv')
gfm_data.head()
# Out:
#   Category                                             Title         Location  \
# 0  Medical                           Justice for Jacob Blake      Kenosha, WI
# 1  Medical       Official Navajo Nation COVID-19 Relief Fund  Window Rock, AZ
# 2  Medical  Help a front line nurse and baby get proper care     Randolph, NJ
# 3  Medical                Rest up, Tommy, we'll see you soon   Scottsdale, AZ
# 4  Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND        Tyler, TX
#
#    Amount_Raised       Goal  Days_of_Fundraising Number_of_Donors FB_Shares  \
# 0      2297930.0  3000000.0                   93            72.5K      118K
# 1      1862040.0  1000000.0                  205            21.9K     71.7K
# 2       954793.0  1200000.0                  215            18.3K     16.4K
# 3       673179.0  1000000.0                  131            10.3K     21.3K
# 4       570529.0   750000.0                  175            24.3K      5.5K
#
#                                                 Text
# 0  On August 23rd my son was shot multiple times ...
# 1  The Navajo Nation COVID-19 Fund has been estab...
# 2  On Sunday, April 12, Sylvia Leroy, a pregnant ...
# 3  First, thank you for being here. Tommy Rivers ...
# 4  My name is Melissa Green and I am the mother o...

# %% [markdown]
# Here, each row represents a different fundraiser, also called a campaign.
#
# There are nine columns of data, reading from left to right:
#
# 1. `Category`: Describes the type of fundraiser. There are 14 different categories of fundraiser represented in our dataset: 'Animals', 'Business', 'Community', 'Competition', 'Creative', 'Emergency', 'Event', 'Faith', 'Family', 'Medical', 'Memorial', 'Newlywed', 'Sports', and 'Wishes'.
#
# 2. `Title`: The title of the fundraiser, which describes the fundraiser in a few words.
#
# 3. `Location`: The location where the fundraiser takes place, stored as "city, state", e.g. "San Diego, CA".
#
# 4. `Amount_Raised`: The total amount of money donated, measured in dollars.
#
# 5. `Goal`: The total amount of money that the fundraiser originally hopes to receive (measured in dollars).
#
# 6. `Days_of_Fundraising`: The number of days for which the fundraiser has been actively soliciting donations.
#
# 7. `Number_of_Donors`: The number of people who donated to the fundraiser.
#
# 8. `FB_Shares`: The number of times the fundraiser has been shared through Facebook.
#
# 9. `Text`: The text description that accompanies the fundraiser, usually describing why funds are being raised.
#
# In the `Number_of_Donors` column and the `FB_Shares` column, entries are stored as strings, and large numbers are abbreviated by using "K" to indicate thousands. For example, an entry `3K` would correspond to 3 * 1000 = 3000.
#
# Note that much of the data for each fundraiser is determined by the user who creates the campaign. When creating a campaign, the user selects an appropriate category and title, chooses the location, sets the fundraising goal, and adds the text description.

# %% [markdown]
# As a data scientist, data cleaning is where you will spend a significant portion of your time. This project is no different!
#
# Let's start by examining the `Number_of_Donors` and `FB_Shares` columns. The values in these columns are strings, not integers, so we can't actually do things like compare values numerically. Moreover, some values are in thousands, such as '72.5K', and others are fewer than 1000, such as '366'. Let's get this data in a more usable format.
#
# **Question 3.1.1** Define a function named `convert_units` which converts a string representation of a number to an integer. This function should work whether or not the string representation has a ‘K’ in it (representing thousands).
#
# *Hint*: Use a [string method](https://docs.python.org/3/library/stdtypes.html#string-methods) to deal with the 'K'.

# %%
#your code
def convert_unit(string_rep):
    if string_rep[-1]=="K":
        return float(string_rep.replace("K"," "))*1000
convert_unit("1K")
# Out:
# 1000.0

# %% [markdown]
# **Question 3.1.2.** Overwrite the columns for `Number_of_Donors` and `FB_Shares` with columns of the same name, but containing integers instead of strings. The dataframe should still be named `gfm_data`.
#
# *Note*: The names of all the columns **must** stay the same and the order of the columns **must** stay the same.

# %%
gfm_data["Number_of_Donors"]=gfm_data["Number_of_Donors"].apply(convert_unit)
gfm_data["FB_Shares"]=gfm_data["FB_Shares"].apply(convert_unit)
gfm_data.head()
# Out:
#   Category                                             Title         Location  \
# 0  Medical                           Justice for Jacob Blake      Kenosha, WI
# 1  Medical       Official Navajo Nation COVID-19 Relief Fund  Window Rock, AZ
# 2  Medical  Help a front line nurse and baby get proper care     Randolph, NJ
# 3  Medical                Rest up, Tommy, we'll see you soon   Scottsdale, AZ
# 4  Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND        Tyler, TX
#
#    Amount_Raised       Goal  Days_of_Fundraising  Number_of_Donors  FB_Shares  \
# 0      2297930.0  3000000.0                   93           72500.0   118000.0
# 1      1862040.0  1000000.0                  205           21900.0    71700.0
# 2       954793.0  1200000.0                  215           18300.0    16400.0
# 3       673179.0  1000000.0                  131           10300.0    21300.0
# 4       570529.0   750000.0                  175           24300.0     5500.0
#
#                                                 Text
# 0  On August 23rd my son was shot multiple times ...
# 1  The Navajo Nation COVID-19 Fund has been estab...
# 2  On Sunday, April 12, Sylvia Leroy, a pregnant ...
# 3  First, thank you for being here. Tommy Rivers ...
# 4  My name is Melissa Green and I am the mother o...

# %% [markdown]
# Next, let's add some columns derived from existing columns.
#
# **Question 3.2.** Create a new dataframe called `gfm_campaigns` that has the same columns as `gfm`, plus two more:
#
# 1. `Proportion_Raised`, which has the proportion of the overall goal that the campaign raised. This proportion should be rounded (not truncated) to **3** decimal places.
# 2. `Average_Donation_Amount`, which has the average donation amount per donor. Since this is a dollar amount, it should be rounded (not truncated) to **2** decimal places.

# %%
#your code Here
gfm_campaigns = gfm_data
gfm_campaigns['Proportion_Raised']=(gfm_campaigns['Goal']/(gfm_campaigns['Goal'].sum())).round(3)
gfm_campaigns['Average_Donation_Amount']=(gfm_campaigns['Amount_Raised']/gfm_campaigns['Number_of_Donors']).round(2)
gfm_campaigns.head()
# Out:
#   Category                                             Title         Location  \
# 0  Medical                           Justice for Jacob Blake      Kenosha, WI
# 1  Medical       Official Navajo Nation COVID-19 Relief Fund  Window Rock, AZ
# 2  Medical  Help a front line nurse and baby get proper care     Randolph, NJ
# 3  Medical                Rest up, Tommy, we'll see you soon   Scottsdale, AZ
# 4  Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND        Tyler, TX
#
#    Amount_Raised       Goal  Days_of_Fundraising  Number_of_Donors  FB_Shares  \
# 0      2297930.0  3000000.0                   93           72500.0   118000.0
# 1      1862040.0  1000000.0                  205           21900.0    71700.0
# 2       954793.0  1200000.0                  215           18300.0    16400.0
# 3       673179.0  1000000.0                  131           10300.0    21300.0
# 4       570529.0   750000.0                  175           24300.0     5500.0
#
#                                                 Text  Proportion_Raised  \
# 0  On August 23rd my son was shot multiple times ...              0.023
# 1  The Navajo Nation COVID-19 Fund has been estab...              0.008
# 2  On Sunday, April 12, Sylvia Leroy, a pregnant ...              0.009
# 3  First, thank you for being here. Tommy Rivers ...              0.008
# 4  My name is Melissa Green and I am the mother o...              0.006
#
#    Average_Donation_Amount
# 0                    31.70
# 1                    85.02
# 2                    52.17
# 3                    65.36
# 4                    23.48

# %% [markdown]
# **Question 3.3** Create a new dataframe called `gfm_success`, which has all the information from the `gfm_campaigns` dataframe plus a new column titled `How_Successful` that indicates how successful a campaign was, depending on its `Proportion_Raised`. If x is the proportion raised, we use the table below to define how successful a campaign is.
#
# | Range             | How_Successful |
# | ----------------- | ------------------ |
# | 0.0 $\leq$ x $\leq$ 0.20 | 'highly unsuccessful' |
# | 0.20 $<$ x $\leq$ 0.50 | 'moderately unsuccessful' |
# | 0.50 $<$ x $\leq$ 0.80 | 'moderately successful' |
# | 0.80 $<$ x $<$ 1.0 | 'highly successful' |
# | x $\geq$ 1.0 | 'extremely successful' |

# %%
#your code Here
gfm_success=gfm_campaigns
a=gfm_success['Proportion_Raised']
successful=[]
for i in a:
    if 0.0<=i<=0.20:
        successful.append('highly unsuccessful')
    elif 0.20<=i<=0.50:
        successful.append('moderately unsuccessful')
    elif 0.50<=i<=0.80:
        successful.append('moderately successful')
    elif 0.80<=i<=1.0:
        successful.append('highly successful')
    else:
        successful.append('extremely successful')

gfm_success["How_Successful"]=successful
gfm_success
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# 1     Window Rock, AZ      1862040.0  1000000.0                  205
# 2        Randolph, NJ       954793.0  1200000.0                  215
# 3      Scottsdale, AZ       673179.0  1000000.0                  131
# 4           Tyler, TX       570529.0   750000.0                  175
# ..                ...            ...        ...                  ...
# 833      Brooklyn, NY        17348.0    20000.0                  160
# 834       Brandon, VT        19300.0    17000.0                  200
# 835       Amherst, MA        21435.0   300000.0                  110
# 836  Johnson City, TN        16405.0    70000.0                  173
# 837     Santa Ana, CA        17905.0    50000.0                  147
#
#      Number_of_Donors  FB_Shares  \
# 0             72500.0   118000.0
# 1             21900.0    71700.0
# 2             18300.0    16400.0
# 3             10300.0    21300.0
# 4             24300.0     5500.0
# ..                ...        ...
# 833               NaN        NaN
# 834               NaN     2500.0
# 835               NaN        NaN
# 836               NaN        NaN
# 837               NaN        NaN
#
#                                                   Text  Proportion_Raised  \
# 0    On August 23rd my son was shot multiple times ...              0.023
# 1    The Navajo Nation COVID-19 Fund has been estab...              0.008
# 2    On Sunday, April 12, Sylvia Leroy, a pregnant ...              0.009
# 3    First, thank you for being here. Tommy Rivers ...              0.008
# 4    My name is Melissa Green and I am the mother o...              0.006
# ..                                                 ...                ...
# 833  The need for community and collective healing ...              0.000
# 834  I am 35 years old and was born with cerebral p...              0.000
# 835  Greetings,My name is Nyanyika Banda. I am a ch...              0.002
# 836  My wife, Roni, and I have faced many  health c...              0.001
# 837  No matter where life has lead us, our past for...              0.000
#
#      Average_Donation_Amount       How_Successful
# 0                      31.70  highly unsuccessful
# 1                      85.02  highly unsuccessful
# 2                      52.17  highly unsuccessful
# 3                      65.36  highly unsuccessful
# 4                      23.48  highly unsuccessful
# ..                       ...                  ...
# 833                      NaN  highly unsuccessful
# 834                      NaN  highly unsuccessful
# 835                      NaN  highly unsuccessful
# 836                      NaN  highly unsuccessful
# 837                      NaN  highly unsuccessful
#
# [838 rows x 12 columns]

# %% [markdown]
# Notice that the `Text` column contains the description of the campaign, which visitors to the campaign page will see. As part of this project, we'd like to explore what makes a description successful in raising money. For example, do longer descriptions raise more money or is better to keep things brief? Are there certain keywords like "mother" or "father" associated with better fundraising outcomes? To answer these types of questions, we'll need to look inside the `Text` column. The data cleaning below will help us extract the information we need more easily.
#
# **Question 3.4.** Create a new dataframe called `gfm`, which has all the information from the `gfm_success` dataframe plus a new column called `Num_Chars` with the length of the text description for each campaign, as an int.

# %%
gfm=gfm_success

def Length(x):
    return len(x)

gfm['Num_Chars']=gfm["Text"].apply(Length)
gfm.head()
# Out:
#   Category                                             Title         Location  \
# 0  Medical                           Justice for Jacob Blake      Kenosha, WI
# 1  Medical       Official Navajo Nation COVID-19 Relief Fund  Window Rock, AZ
# 2  Medical  Help a front line nurse and baby get proper care     Randolph, NJ
# 3  Medical                Rest up, Tommy, we'll see you soon   Scottsdale, AZ
# 4  Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND        Tyler, TX
#
#    Amount_Raised       Goal  Days_of_Fundraising  Number_of_Donors  FB_Shares  \
# 0      2297930.0  3000000.0                   93           72500.0   118000.0
# 1      1862040.0  1000000.0                  205           21900.0    71700.0
# 2       954793.0  1200000.0                  215           18300.0    16400.0
# 3       673179.0  1000000.0                  131           10300.0    21300.0
# 4       570529.0   750000.0                  175           24300.0     5500.0
#
#                                                 Text  Proportion_Raised  \
# 0  On August 23rd my son was shot multiple times ...              0.023
# 1  The Navajo Nation COVID-19 Fund has been estab...              0.008
# 2  On Sunday, April 12, Sylvia Leroy, a pregnant ...              0.009
# 3  First, thank you for being here. Tommy Rivers ...              0.008
# 4  My name is Melissa Green and I am the mother o...              0.006
#
#    Average_Donation_Amount       How_Successful  Num_Chars
# 0                    31.70  highly unsuccessful        964
# 1                    85.02  highly unsuccessful        824
# 2                    52.17  highly unsuccessful       1651
# 3                    65.36  highly unsuccessful       1461
# 4                    23.48  highly unsuccessful       1241

# %% [markdown]
# **Question 3.5** Overwrite the `Text` column in the `gfm` dataframe so that all the descriptions appear in lowercase.
#
# *Hint:* Check out Python's built-in [string methods](https://docs.python.org/3/library/stdtypes.html#string-methods).

# %%
#your code here
a=gfm["Text"]
text=[]

for i in a:
    text.append(i.lower())
        
    
gfm["Text"]=text
gfm.head()
# Out:
#   Category                                             Title         Location  \
# 0  Medical                           Justice for Jacob Blake      Kenosha, WI
# 1  Medical       Official Navajo Nation COVID-19 Relief Fund  Window Rock, AZ
# 2  Medical  Help a front line nurse and baby get proper care     Randolph, NJ
# 3  Medical                Rest up, Tommy, we'll see you soon   Scottsdale, AZ
# 4  Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND        Tyler, TX
#
#    Amount_Raised       Goal  Days_of_Fundraising  Number_of_Donors  FB_Shares  \
# 0      2297930.0  3000000.0                   93           72500.0   118000.0
# 1      1862040.0  1000000.0                  205           21900.0    71700.0
# 2       954793.0  1200000.0                  215           18300.0    16400.0
# 3       673179.0  1000000.0                  131           10300.0    21300.0
# 4       570529.0   750000.0                  175           24300.0     5500.0
#
#                                                 Text  Proportion_Raised  \
# 0  on august 23rd my son was shot multiple times ...              0.023
# 1  the navajo nation covid-19 fund has been estab...              0.008
# 2  on sunday, april 12, sylvia leroy, a pregnant ...              0.009
# 3  first, thank you for being here. tommy rivers ...              0.008
# 4  my name is melissa green and i am the mother o...              0.006
#
#    Average_Donation_Amount       How_Successful  Num_Chars
# 0                    31.70  highly unsuccessful        964
# 1                    85.02  highly unsuccessful        824
# 2                    52.17  highly unsuccessful       1651
# 3                    65.36  highly unsuccessful       1461
# 4                    23.48  highly unsuccessful       1241

# %% [markdown]
# **Question 3.6.** Set `cutoff` to be the smallest number of characters for which we will consider a text description to be long, if we want the groups to be about the same size.
#
# *Hint*: We may not be able to split the dataset into groups of the exact same size. What is the best we can do? Use a measure of center.

# %%
gfm['Num_Chars'].value_counts()
# Out:
# 2017    4
# 1030    4
# 729     4
# 3346    3
# 1301    3
#        ..
# 1021    1
# 2707    1
# 3730    1
# 1681    1
# 1494    1
# Name: Num_Chars, Length: 748, dtype: int64

# %%
gfm.Num_Chars.mode(),gfm.Num_Chars.mean(),gfm.Num_Chars.median()
# Out:
# (0     729
#  1    1030
#  2    2017
#  dtype: int64,
#  1938.2756563245823,
#  1486.0)

# %%
cutoff=gfm.Num_Chars.mode()[0]
cutoff
# Out:
# 729

# %% [markdown]
# Now define a long description to be a description where the number of characters is ***at least*** as long as `cutoff` and a short description to be a description where the number of characters is less than `cutoff`.
# Make 2 dataframe for long and short

# %%
#your code Here
long_desp=gfm[gfm['Num_Chars']>cutoff]
long_desp.head()
# Out:
#   Category                                             Title         Location  \
# 0  Medical                           Justice for Jacob Blake      Kenosha, WI
# 1  Medical       Official Navajo Nation COVID-19 Relief Fund  Window Rock, AZ
# 2  Medical  Help a front line nurse and baby get proper care     Randolph, NJ
# 3  Medical                Rest up, Tommy, we'll see you soon   Scottsdale, AZ
# 4  Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND        Tyler, TX
#
#    Amount_Raised       Goal  Days_of_Fundraising  Number_of_Donors  FB_Shares  \
# 0      2297930.0  3000000.0                   93           72500.0   118000.0
# 1      1862040.0  1000000.0                  205           21900.0    71700.0
# 2       954793.0  1200000.0                  215           18300.0    16400.0
# 3       673179.0  1000000.0                  131           10300.0    21300.0
# 4       570529.0   750000.0                  175           24300.0     5500.0
#
#                                                 Text  Proportion_Raised  \
# 0  on august 23rd my son was shot multiple times ...              0.023
# 1  the navajo nation covid-19 fund has been estab...              0.008
# 2  on sunday, april 12, sylvia leroy, a pregnant ...              0.009
# 3  first, thank you for being here. tommy rivers ...              0.008
# 4  my name is melissa green and i am the mother o...              0.006
#
#    Average_Donation_Amount       How_Successful  Num_Chars
# 0                    31.70  highly unsuccessful        964
# 1                    85.02  highly unsuccessful        824
# 2                    52.17  highly unsuccessful       1651
# 3                    65.36  highly unsuccessful       1461
# 4                    23.48  highly unsuccessful       1241

# %%
short_desp=gfm[gfm['Num_Chars']<cutoff]
short_desp.head()
# Out:
#    Category                                              Title  \
# 5   Medical  Helping Laura and Katherine get through my death.
# 35  Medical                        Love and Support for Leslie
# 40  Medical                       Angelette Family Relief Fund
# 41  Medical  Lenora Farrington, Brutally Attacked at Open H...
# 69  Medical                              Help the Power Family
#
#                      Location  Amount_Raised      Goal  Days_of_Fundraising  \
# 5                  Eugene, OR       423013.0  200000.0                   55
# 35              San Diego, CA       175978.0  250000.0                  178
# 40              Covington, LA       167009.0  200000.0                  118
# 41                 Forest, VA       167756.0  250000.0                  157
# 69  Village of Wellington, FL       120897.0  150000.0                  141
#
#     Number_of_Donors  FB_Shares  \
# 5             9700.0     1500.0
# 35            7400.0    10900.0
# 40            1300.0     8100.0
# 41            2900.0    70500.0
# 69            1600.0    13000.0
#
#                                                  Text  Proportion_Raised  \
# 5   i am dying of lymphoma. my wife, laura, has be...              0.002
# 35  on behalf of leslie and her family we are aski...              0.002
# 40  elise angelette, mother of 5, was diagnosed wi...              0.002
# 41  hi, my name is teresa grant with keller willia...              0.002
# 69  this go fund me is for the power family. they ...              0.001
#
#     Average_Donation_Amount       How_Successful  Num_Chars
# 5                     43.61  highly unsuccessful        404
# 35                    23.78  highly unsuccessful        379
# 40                   128.47  highly unsuccessful        706
# 41                    57.85  highly unsuccessful        591
# 69                    75.56  highly unsuccessful        470

# %% [markdown]
# Next, we can run some text analysis to determine whether specific words in the `Text` are associated with a higher or lower `Average_Donation_Amount`. More specifically, do donors find specific words found in the description of a campaign impactful? For example, we might conjecture that words relating to family like "father", "daughter", "son", etc. are associated with higher average donation amounts.
#
# Which *three* words do you think are impactful to donors? Store any three lowercase words you think are linked to higher average donations in a list called `impactful_words`.

# %%
impactful_words=...

# %% [markdown]
# **Question 3.7** Create a new dataframe called `gfm_impactful`, which contains the information from `gfm` plus a column named `Has_Impactful` which is True/False depending whether the campaign contains at least one impactful word or not.

# %%
#your code here
gfm_impactful=...

# %% [markdown]
# ## 4. Google Play Store
#
# In this problem, we will explore the [Google Play Store Apps Dataset](https://www.kaggle.com/lava18/google-play-store-apps), scraped from the Google Play Store.

# %%
# run this cell to load the data
apps = pd.read_csv('S:/ML/datasets/googleplaystore.csv')
apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# Each row in the table is an app. Here are descriptions of some of the columns.
# - **Category** Category the app belongs to
# - **Rating** Overall user rating of the app (as when scraped)
# - **Reviews** Number of user reviews for the app (as when scraped)
# - **Installs** Number of user downloads/installs for the app (as when scraped)
#
# Notice that we did not set the index, even though it looks like the app name would be a good candidate. This is because the app names are not unique! We can verify this with the help of a `numpy` function called `np.unique`. This function takes in an array and outputs an array with all duplicates removed.
#
# We see above that the table has 10,825 rows. This means that there are 10,825 apps in the dataset. But let's calculate how many unique names there are:

# %%
len(np.unique(apps.get('App')))
# Out:
# 9660

# %% [markdown]
# So there must be duplicates!
#
# Because there are duplicates, the app name is not a good row label. In fact, there is no good row label in this case. In situations like this, we'll leave the index as-is.

# %% [markdown]
# **Question 4.1.** Assign `by_content` to a dataframe which counts the number of apps per Content Rating. List the Content Ratings alphabetically.
# <br>
# Hint:You can use groupby

# %%
#your code here
by_content=apps.groupby('Content Rating')
df=pd.DataFrame(by_content["App"].count())
df
# Out:
#                   App
# Content Rating
# Adults only 18+     3
# Everyone         8714
# Everyone 10+      414
# Mature 17+        499
# Teen             1208
# Unrated             2

# %% [markdown]
# **Question 4.2.** Compute the number of apps in the dataset that have 1.5 stars or lower, and save the result in `bad_apps` and compute the number of apps in the dataset that have 4 stars or higher, and save the results in `good_apps`.

# %%
bad_apps=apps[apps['Rating']<=1.5]
bad_apps.head()
# Out:
#                                 App            Category  Rating Reviews  Size  \
# 625         House party - live chat              DATING     1.0       1  9.2M
# 4127              Speech Therapy: F              FAMILY     1.0       1   16M
# 5151                  Clarksburg AH             MEDICAL     1.0       1   28M
# 5978  Truck Driving Test Class 3 BC              FAMILY     1.0       1  2.0M
# 6008                BD Provider App  HEALTH_AND_FITNESS     1.4      45   13M
#
#      Installs  Type  Price Content Rating            Genres  \
# 625       10+  Free      0     Mature 17+            Dating
# 4127      10+  Paid  $2.99       Everyone         Education
# 5151      50+  Free      0       Everyone           Medical
# 5978      50+  Paid  $1.49       Everyone         Education
# 6008   5,000+  Free      0       Everyone  Health & Fitness
#
#             Last Updated  Current Ver   Android Ver
# 625        July 31, 2018         3.52  4.0.3 and up
# 4127     October 7, 2016          1.0  2.3.3 and up
# 5151         May 1, 2017  300000.0.81  4.0.3 and up
# 5978       April 9, 2012          1.0    2.1 and up
# 6008  September 12, 2016          1.0    4.1 and up

# %%
good_apps=apps[apps['Rating']>=4]
good_apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
#
#                     Genres     Last Updated         Current Ver   Android Ver
# 0             Art & Design  January 7, 2018               1.0.0  4.0.3 and up
# 2             Art & Design   August 1, 2018               1.2.4  4.0.3 and up
# 3             Art & Design     June 8, 2018  Varies with device    4.2 and up
# 4  Art & Design;Creativity    June 20, 2018                 1.1    4.4 and up
# 5             Art & Design   March 26, 2017                 1.0    2.3 and up

# %% [markdown]
# **Question 4.3.** How many apps listed have the word "Google" (with that exact capitalization) in the App name? Save the number as `google_apps`.
#
# Note: each row is a separate App and should be counted as such (even if the names are the same).

# %%
#your code here
Google_apps=0
a=apps['App']
for i in a:
    if "Google" in i:
        Google_apps += 1

# %%
Google_apps
# Out:
# 94

# %% [markdown]
# **Question 4.4.** Of the apps under the Category `COMMUNICATION`, get the `Content Rating` count for apps where the Rating is between or equal to 4 and 5 (inclusive). Return this as a table sorted by `count` (with greatest count at the top of the table) called `top_communication_apps`.
#
# Hint: creating two Dataframes may help. Even though it is possible to do this in one line, sometimes it's better to break up the tasks to make the overall process clearer. We will only check the final table though.

# %%
#your code here
apps['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
app_cat=apps.groupby("Category")
comm_app=app_cat.get_group('COMMUNICATION')
top_app=comm_app[(comm_app['Rating']>=4) & (comm_app['Rating']>=5)]

# %%
top_app.sort_values(by='Rating',ascending=False).head()
# Out:
#                App       Category  Rating Reviews  Size Installs  Type Price  \
# 6727     BS-Mobile  COMMUNICATION     5.0       1  683k      50+  Free     0
# 6852            BV  COMMUNICATION     5.0       3  1.6M     100+  Free     0
# 7142    Cb browser  COMMUNICATION     5.0       5  3.7M      50+  Free     0
# 9119       chat dz  COMMUNICATION     5.0       8   29M     100+  Free     0
# 9455  EJ messenger  COMMUNICATION     5.0       1   25M      10+  Free     0
#
#      Content Rating         Genres       Last Updated Current Ver Android Ver
# 6727       Everyone  Communication  September 3, 2015         0.1  2.3 and up
# 6852       Everyone  Communication     August 4, 2016        1,01  3.0 and up
# 7142       Everyone  Communication      April 2, 2018         1.0  4.0 and up
# 9119           Teen  Communication     March 14, 2018         1.0  4.1 and up
# 9455           Teen  Communication   October 18, 2017         1.0  4.0 and up

# %% [markdown]
# **Question 4.5.** Create a table named `install_stats` which has a single column, `Installs`, which contains the mean number of install of apps in each type of content rating.

# %%
#your code here
apps['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
def clear_str_1(a):
    return a.replace("+","")

def clear_str_2(a):
    return a.replace("Free","0")

def clear_str_3(a):
    return a.replace(",","")

apps['Installs']=apps['Installs'].apply(clear_str_1)
apps['Installs']=apps['Installs'].apply(clear_str_2)
apps['Installs']=apps['Installs'].apply(clear_str_3)

apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
apps['Installs']=apps['Installs'].astype(int)
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  int32
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 1.0+ MB

# %%
apps_cont=apps.groupby("Content Rating")
apps_cont.Installs.mean()
# Out:
# Content Rating
# Adults only 18+    6.666667e+05
# Everyone           1.310037e+07
# Everyone 10+       3.196590e+07
# Mature 17+         1.107112e+07
# Teen               2.873870e+07
# Unrated            2.525000e+04
# Name: Installs, dtype: float64

# %% [markdown]
# **Question4.6.** Suppose a good app is one with at least one million installs and a rating of at least 4.0. Create a variable called `best_category` containing the name of the category with the most good apps.

# %%
#your code here
best_category=apps['Category'][(apps['Installs']>=1000000)&(apps['Rating']>=4.0)]
best_category
# Out:
# 2        ART_AND_DESIGN
# 3        ART_AND_DESIGN
# 7        ART_AND_DESIGN
# 8        ART_AND_DESIGN
# 10       ART_AND_DESIGN
#               ...
# 10797         LIFESTYLE
# 10803              GAME
# 10809            FAMILY
# 10826            SOCIAL
# 10840         LIFESTYLE
# Name: Category, Length: 3899, dtype: object

# %% [markdown]
# **Question 4.7.** Make a bar chart of the average rating by category in which the bars are sorted from smallest to largest.

# %%
#your code here
cat_apps=apps.groupby('Category')
df=pd.DataFrame(cat_apps.Rating.mean())
df=df.sort_values(by='Rating')
x=df['Rating']
y=df.index
plt.figure(figsize=(10,6))
plt.bar(y,x)
plt.xlabel('Category',fontsize=14)
plt.ylabel('Rating',fontsize=14)
plt.xticks(rotation='vertical')
plt.title('Category vs Rating',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Category vs Rating')

# %% [markdown]
# ## 5. Histograms
# Earlier, we computed the average pay among the CEOs in our 102-CEO dataset.  The average doesn't tell us everything about the amounts CEOs are paid, though.  Maybe just a few CEOs make the bulk of the money, even among these 102.

# %% [markdown]
# **Question 5.1.** Make a histogram of the pay of the CEOs in compensation

# %%
#your code Here
plt.hist(compensation['Total_Pay_Dollars'])
plt.title("Total Pay of CEO's in Dollars")
# Out:
# Text(0.5, 1.0, "Total Pay of CEO's in Dollars")

# %% [markdown]
# **Question 5.2.** Looking at the histogram, about how many CEOs made more than $30 million? Make a good guess. (Answer the question by filling in your answer manually. You'll have to do a bit of arithmetic; feel free to use Python as a calculator.)

# %%
#your code here
num_ceos_more_than_30_million = 5
num_ceos_more_than_30_million
# Out:
# 5

# %% [markdown]
# **Question 5.3.** Answer the same question with code.

# %%
#your code here
num_ceos_more_than_30_million_2=compensation["Total_Pay_Dollars"][compensation["Total_Pay_Dollars"]>=30].count()
num_ceos_more_than_30_million_2
# Out:
# 5

# %% [markdown]
# Run the next cell if you want to see how far off you were.

# %%
percent_diff = abs(num_ceos_more_than_30_million - num_ceos_more_than_30_million_2) / num_ceos_more_than_30_million_2
print("Your guess was only", percent_diff * 100, "% off!")
# Out:
# Your guess was only 0.0 % off!

# %% [markdown]
# ### Finish Line
